# %% [markdown]
# ### Sarthak & Sidhant

# %%
import os
import ujson
import gzip
import pandas as pd
import gc

# %% [markdown]
# ### Load Review Data

# %%
data = []
with open('Electronics Dataset/Electronics.json') as f:
    for l in f:
        data.append(ujson.loads(l.strip()))
    
print(len(data))
# Out:
# 20994353

# %%
# first row of the list
print(data[0])
# Out:
# {'overall': 5.0, 'verified': True, 'reviewTime': '07 17, 2002', 'reviewerID': 'A1N070NS9CJQ2I', 'asin': '0060009810', 'style': {'Format:': ' Hardcover'}, 'reviewerName': 'Teri Adams', 'reviewText': "This was the first time I read Garcia-Aguilera.  I came upon the name of this book on Live with Regis and Kelly. This book was exactly what I was looking for ... it hit the spot.  I really enjoyed this book because it was well written. Once I started this book it kept me coming back for more. It had culture, family, friendship and romance. I was looking for a little more romance when I picked this book but in the end it turned out to be just right.  I love the main chartachter Margarita (aka Daisy). I've never been to Miami but the way Daisy told the story I certainly felt I'd been there.\nAlso after going through all of Daisy's perils ... I closed the book with a feeling I had grown emotionally as well.", 'summary': 'Hit The Spot!', 'unixReviewTime': 1026864000}

# %%
df_reviews = pd.DataFrame.from_dict(data)

print(len(df_reviews))
# Out:
# 20994353

# %%
del data
gc.collect()
# Out:
# 0

# %%
df_reviews.shape
# Out:
# (20994353, 12)

# %% [markdown]
# ### Columns for Review Data

# %%
len(df_reviews.columns)
# Out:
# 12

# %%
for i in df_reviews.columns:
    print(i)
# Out:
# overall
# verified
# reviewTime
# reviewerID
# asin
# style
# reviewerName
# reviewText
# summary
# unixReviewTime
# vote
# image

# %%
df_reviews.head(110)
# Out:
#      overall  verified   reviewTime      reviewerID        asin  \
# 0        5.0      True  07 17, 2002  A1N070NS9CJQ2I  0060009810
# 1        5.0     False   07 6, 2002  A3P0KRKOBQK1KN  0060009810
# 2        5.0     False   07 3, 2002  A192HO2ICJ75VU  0060009810
# 3        4.0     False  06 30, 2002  A2T278FKFL3BLT  0060009810
# 4        5.0     False  06 28, 2002  A2ZUXVTW8RXBXW  0060009810
# ..       ...       ...          ...             ...         ...
# 105      5.0     False  08 30, 2000   AN5RSF8TJ62NW  0151004714
# 106      3.0     False  03 21, 2000  A1IWWRZJOXOSYP  0151004714
# 107      3.0      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
# 108      5.0     False  01 15, 2000  A2CGDQGHUN3DMM  0151004714
# 109      5.0     False   12 5, 1999  A3QLL55JUBXDNT  0151004714
#
#                          style          reviewerName  \
# 0    {'Format:': ' Hardcover'}            Teri Adams
# 1    {'Format:': ' Hardcover'}              Willa C.
# 2    {'Format:': ' Hardcover'}                   Kit
# 3    {'Format:': ' Hardcover'}                Andres
# 4    {'Format:': ' Hardcover'}                  John
# ..                         ...                   ...
# 105  {'Format:': ' Hardcover'}        natasha lovett
# 106  {'Format:': ' Hardcover'}         Lee Armstrong
# 107  {'Format:': ' Hardcover'}      W. Shane Schmidt
# 108  {'Format:': ' Hardcover'}              Trapicia
# 109  {'Format:': ' Hardcover'}  Dr. Richard S. Beach
#
#                                             reviewText  \
# 0    This was the first time I read Garcia-Aguilera...
# 1    As with all of Ms. Garcia-Aguilera's books, I ...
# 2    I've not read any of Ms Aguilera's works befor...
# 3    This romance novel is right up there with the ...
# 4    Carolina Garcia Aguilera has done it again.  S...
# ..                                                 ...
# 105  this book is a very good one i love the way th...
# 106  Perhaps this is a novel more for women.  Like ...
# 107  I was taken in by reviews that compared this b...
# 108  This was one of the best books I read in 1999....
# 109  Just a stunning achievement, this book builds ...
#
#                                                summary  unixReviewTime vote  \
# 0                                        Hit The Spot!      1026864000  NaN
# 1                       one hot summer is HOT HOT HOT!      1025913600  NaN
# 2                                       One Hot Summer      1025654400    2
# 3                                    I love this book!      1025395200    3
# 4                                         One Hot Book      1025222400  NaN
# ..                                                 ...             ...  ...
# 105                      One of the best stories ever.       967593600    4
# 106  Washes over the reader as a series of experiences       953596800  NaN
# 107                        A dissenting view--In part.       949622400    8
# 108                               Hauntingly Beautiful       947894400   13
# 109                     as if 5 stars were enough.....       944352000   14
#
#     image
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 105   NaN
# 106   NaN
# 107   NaN
# 108   NaN
# 109   NaN
#
# [110 rows x 12 columns]

# %% [markdown]
# ### Extracting Verified Reviews Only

# %%
verified_count = 0
for i in df_reviews['verified']:
    if i:
        verified_count += 1

# %%
print("% of verified reviews = {}%".format((verified_count/len(df_reviews))*100))
# Out:
# % of verified reviews = 88.58140091290264%

# %%
df_verified_reviews = df_reviews[df_reviews.verified == True]

# %%
len(df_verified_reviews)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lj/zw8215sd2klbg95184tl21yh0000gn/T/ipykernel_1941/4246087597.py in <module>
# ----> 1 len(df_verified_reviews)
#
# NameError: name 'df_verified_reviews' is not defined

# %%
df_verified_reviews.head()
# Out:
#     overall  verified   reviewTime      reviewerID        asin  \
# 0       5.0      True  07 17, 2002  A1N070NS9CJQ2I  0060009810
# 15      4.0      True   08 5, 2007  A1X7HRXX3BJXQ8  0060786817
# 24      4.0      True   07 9, 2006  A27385LU50J4JJ  0060786817
# 28      3.0      True  05 23, 2006   AC0N6E128OYZH  0060786817
# 30      5.0      True   05 8, 2006  A12CK830R4WVMY  0060786817
#
#                         style         reviewerName  \
# 0   {'Format:': ' Hardcover'}           Teri Adams
# 15  {'Format:': ' Hardcover'}             a reader
# 24  {'Format:': ' Hardcover'}        Kim Burlee F.
# 28  {'Format:': ' Hardcover'}       Paula Marshall
# 30  {'Format:': ' Hardcover'}  Sydney Molare&#039;
#
#                                            reviewText  \
# 0   This was the first time I read Garcia-Aguilera...
# 15  EXTREME WARNING: Unless your computer has upda...
# 24  I bought this book thinking that it was the no...
# 28  This was the second book that I've read by thi...
# 30  I've read the Reesy and Misty novels and was n...
#
#                                               summary  unixReviewTime vote  \
# 0                                       Hit The Spot!      1026864000  NaN
# 15  Suckers Always Pay For Beauty----One Way or An...      1186272000  NaN
# 24                                  Kim's thoughts...      1152403200    2
# 28                                  I Couldn't Finish      1148342400    4
# 30                                 Best Work to Date!      1147046400  NaN
#
#    image
# 0    NaN
# 15   NaN
# 24   NaN
# 28   NaN
# 30   NaN

# %% [markdown]
# ### Load Product MetaData

# %%
metadata = pd.read_pickle('Electronics Dataset/Filtered_Electronics.pkl')

# %%
len(metadata)
# Out:
# 129569

# %%
metadata.head()
# Out:
#                                              category tech1  \
# 7   [Electronics, Portable Audio & Video, MP3 & MP...
# 14  [Electronics, eBook Readers &amp; Accessories,...
# 37  [Electronics, Accessories &amp; Supplies, Audi...
# 38  [Electronics, GPS, Finders & Accessories, GPS ...
# 39  [Electronics, GPS, Finders &amp; Accessories, ...
#
#                                           description fit  \
# 7   [Support system: Windows XP/Vsita/7 * SNR: 85d...
# 14                                                 []
# 37  [The CLIKR-5 UR5U-8780L remote control is desi...
# 38  [Award-winning navigation and features of Rand...
# 39  [The Road Explorer  60 pairs award-winning nav...
#
#                                                 title  \
# 7   abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 14  BOOX Max Carta Ereader,13.3" Flexible Screen 1...
# 37  CLIKR-5 Time Warner Cable Remote Control UR5U-...
# 38                          Rand McNally RV Tablet 80
# 39                  Rand McNally Road Explorer 60 GPS
#
#                                              also_buy tech2         brand  \
# 7   [B01NAJ3KQB, B00WYSPT0C, B00AF40U5G, B00OFVNM4...          Crazy Cart
# 14                                                 []                BOOX
# 37                           [B06VTZK822, B00OSI6O7S]                 URC
# 38                                       [B000BUQOGI]        Rand McNally
# 39                                                 []        Rand McNally
#
#                                               feature  \
# 7   [Package Content: 1 x Display MP3 Player 1 x E...
# 14  [Excellent Pinch Zooming Experience  -- Highli...
# 37                      [Instruction manual included]
# 38  [Advanced navigation & trip planning, Wi-Ficon...
# 39  [Award-winning navigation, Advanced, commercia...
#
#                                                  rank  \
# 7   [>#177,454 in Electronics (See Top 100 in Elec...
# 14  [>#264,331 in Electronics (See Top 100 in Elec...
# 37  [>#4,971 in Electronics &gt; Accessories &amp;...
# 38  [>#4,892 in Electronics > Accessories & Suppli...
# 39  [>#177 in Electronics &gt; Accessories &amp; S...
#
#                                             also_view         main_cat  \
# 7   [B01NAJ3KQB, B00OFVNM4G, B00L41WY8K, B07F34PNP...  All Electronics
# 14  [B077GVLMJN, B07BNGJXGS, B072DXXXN1, B07BYKZ9P...  All Electronics
# 37  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 38  [B01N5Q2YMO, B00YY3UBV2, B06XCBK7WB, B00CZ6WFX...  All Electronics
# 39  [B017WKSI3Q, B00N58RZ34, B07FKR7VZ4, B06XYPNDC...  All Electronics
#
#                                          similar_item               date  \
# 7    class="a-bordered a-horizontal-stripes  a-spa...  December 28, 2012
# 14   class="a-bordered a-horizontal-stripes  a-spa...      June 30, 2016
# 37   class="a-bordered a-horizontal-stripes  a-spa...   January 31, 2013
# 38   class="a-bordered a-horizontal-stripes  a-spa...   October 23, 2015
# 39                                                        April 30, 2015
#
#    price        asin                                           imageURL  \
# 7         0101635370  [https://images-na.ssl-images-amazon.com/image...
# 14        0285175270  [https://images-na.ssl-images-amazon.com/image...
# 37        0511189877  [https://images-na.ssl-images-amazon.com/image...
# 38        0528013475  [https://images-na.ssl-images-amazon.com/image...
# 39        0528012398  [https://images-na.ssl-images-amazon.com/image...
#
#                                       imageURLHighRes details
# 7   [https://images-na.ssl-images-amazon.com/image...     NaN
# 14  [https://images-na.ssl-images-amazon.com/image...     NaN
# 37  [https://images-na.ssl-images-amazon.com/image...     NaN
# 38  [https://images-na.ssl-images-amazon.com/image...     NaN
# 39  [https://images-na.ssl-images-amazon.com/image...     NaN

# %% [markdown]
# ### Merge Review and Product Dataset

# %%
merged_data = pd.merge(df_reviews, metadata, on='asin',how='inner')

# %%
merged_data.to_picklele("merged_data.pkl")

# %%
len(merged_data)
# Out:
# 4009885

# %%
len(merged_data.columns)
# Out:
# 30

# %%
for i in merged_data.columns:
    print(i)
# Out:
# overall
# verified
# reviewTime
# reviewerID
# asin
# style
# reviewerName
# reviewText
# summary
# unixReviewTime
# vote
# image
# category
# tech1
# description
# fit
# title
# also_buy
# tech2
# brand
# feature
# rank
# also_view
# main_cat
# similar_item
# date
# price
# imageURL
# imageURLHighRes
# details

# %%
merged_data.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin style  \
# 0      2.0     False  04 14, 2014  A3J3BRHTDRFJ2G  0511189877   NaN
# 1      5.0      True  04 14, 2014  A1QGNMC6O1VW39  0511189877   NaN
# 2      5.0      True  03 27, 2014  A2TY0BTJOTENPG  0511189877   NaN
# 3      5.0      True  03 23, 2014  A34ATBPOK6HCHY  0511189877   NaN
# 4      5.0      True  03 22, 2014   A89DO69P0XZ27  0511189877   NaN
#
#        reviewerName                                         reviewText  \
# 0          EJ Honda  This remote, for whatever reason, was chosen b...
# 1                CK  Dog got the old remote and destroyed it.  Didn...
# 2    Goblinthrasher  We had an old Time Warner Cable remote that wa...
# 3  Nancy C. Johnson  This unit works just like the TEC unit only be...
# 4   Stephen Schultz  It is an exact duplicate of my Time warner rem...
#
#                                              summary  unixReviewTime  ...  \
# 0                                Ergonomic nightmare      1397433600  ...
# 1                        Works Great with my TWC box      1397433600  ...
# 2  Excellent replacement to Time Warner Cable remote      1395878400  ...
# 3                                        Great piece      1395532800  ...
# 4                           Time Warner cable remote      1395446400  ...
#
#                          feature  \
# 0  [Instruction manual included]
# 1  [Instruction manual included]
# 2  [Instruction manual included]
# 3  [Instruction manual included]
# 4  [Instruction manual included]
#
#                                                 rank  \
# 0  [>#4,971 in Electronics &gt; Accessories &amp;...
# 1  [>#4,971 in Electronics &gt; Accessories &amp;...
# 2  [>#4,971 in Electronics &gt; Accessories &amp;...
# 3  [>#4,971 in Electronics &gt; Accessories &amp;...
# 4  [>#4,971 in Electronics &gt; Accessories &amp;...
#
#                                            also_view         main_cat  \
# 0  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 1  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 2  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 3  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 4  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
#
#                                         similar_item              date price  \
# 0   class="a-bordered a-horizontal-stripes  a-spa...  January 31, 2013
# 1   class="a-bordered a-horizontal-stripes  a-spa...  January 31, 2013
# 2   class="a-bordered a-horizontal-stripes  a-spa...  January 31, 2013
# 3   class="a-bordered a-horizontal-stripes  a-spa...  January 31, 2013
# 4   class="a-bordered a-horizontal-stripes  a-spa...  January 31, 2013
#
#                                             imageURL  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                      imageURLHighRes details
# 0  [https://images-na.ssl-images-amazon.com/image...     NaN
# 1  [https://images-na.ssl-images-amazon.com/image...     NaN
# 2  [https://images-na.ssl-images-amazon.com/image...     NaN
# 3  [https://images-na.ssl-images-amazon.com/image...     NaN
# 4  [https://images-na.ssl-images-amazon.com/image...     NaN
#
# [5 rows x 30 columns]

# %%
merged_data.iloc[0]
# Out:
# overall                                                          2.0
# verified                                                       False
# reviewTime                                               04 14, 2014
# reviewerID                                            A3J3BRHTDRFJ2G
# asin                                                      0511189877
# style                                                            NaN
# reviewerName                                                EJ Honda
# reviewText         This remote, for whatever reason, was chosen b...
# summary                                          Ergonomic nightmare
# unixReviewTime                                            1397433600
# vote                                                              12
# image                                                            NaN
# category           [Electronics, Accessories &amp; Supplies, Audi...
# tech1
# description        [The CLIKR-5 UR5U-8780L remote control is desi...
# fit
# title              CLIKR-5 Time Warner Cable Remote Control UR5U-...
# also_buy                                    [B06VTZK822, B00OSI6O7S]
# tech2
# brand                                                            URC
# feature                                [Instruction manual included]
# rank               [>#4,971 in Electronics &gt; Accessories &amp;...
# also_view          [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...
# main_cat                                             All Electronics
# similar_item        class="a-bordered a-horizontal-stripes  a-spa...
# date                                                January 31, 2013
# price
# imageURL           [https://images-na.ssl-images-amazon.com/image...
# imageURLHighRes    [https://images-na.ssl-images-amazon.com/image...
# details                                                          NaN
# Name: 0, dtype: object

# %% [markdown]
# ### Filtering Verified Reviews

# %%
merged_verified = merged_data[merged_data.verified == True]

# %%
merged_verified.to_pickle("verified_merged_reviews.pkl")

# %% [markdown]
# ### Handling Missing Values

# %%
merged_verified.isnull().sum()
# Out:
# overall                  0
# verified                 0
# reviewTime               0
# reviewerID               0
# asin                     0
# style              1828110
# reviewerName           236
# reviewText            1172
# summary                621
# unixReviewTime           0
# vote               2975595
# image              3332886
# category                 0
# tech1                    0
# description              0
# fit                      0
# title                    0
# also_buy                 0
# tech2                    0
# brand                    0
# feature                  0
# rank                     0
# also_view                0
# main_cat                 0
# similar_item             0
# date                     0
# price                    0
# imageURL                 0
# imageURLHighRes          0
# details               2261
# dtype: int64
