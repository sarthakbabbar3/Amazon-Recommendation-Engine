# %% [markdown]
# ### Sarthak & Sidhant

# %%
import os
import ujson
import gzip
import pandas as pd
import numpy as np
from collections import Counter

# %% [markdown]
# ### Load Electronics Meta Data

# %%
data = []
with open('meta_Electronics.json') as f:
    for l in f:
        data.append(ujson.loads(l.strip()))
    
print(len(data))
# Out:
# 786445

# %%
# first row of the list
print(data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-0fc601c4932d> in <module>
#       1 # first row of the list
# ----> 2 print(data[0])
#
# NameError: name 'data' is not defined

# %%
df_reviews = pd.DataFrame.from_dict(data)

print(len(df_reviews))
# Out:
# 786445

# %%
df_reviews.shape
# Out:
# (786445, 19)

# %% [markdown]
# ### Clearing data variable to free up space

# %%
import gc

del data
gc.collect()
# Out:
# 15

# %% [markdown]
# ### Columns for Review Data

# %%
### finding unique attribute values of main_cat(main category)
pd.unique(df_reviews['main_cat'])
# Out:
# array(['Camera &amp; Photo', 'Books', 'All Electronics',
#        'Home Audio & Theater', 'Computers', 'Home Audio &amp; Theater',
#        'Portable Audio &amp; Accessories', 'Portable Audio & Accessories',
#        'Cell Phones &amp; Accessories', 'Office Products',
#        'Sports &amp; Outdoors', 'GPS &amp; Navigation',
#        'Toys &amp; Games', 'Software', 'GPS & Navigation',
#        'Camera & Photo', 'Cell Phones & Accessories', 'Amazon Home',
#        'Arts, Crafts &amp; Sewing', 'Baby', 'Car Electronics',
#        'Toys & Games', 'Health &amp; Personal Care',
#        'Tools & Home Improvement', 'Arts, Crafts & Sewing',
#        'Musical Instruments', 'Pet Supplies', 'Sports & Outdoors',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#        'Amazon Devices', 'Tools &amp; Home Improvement',
#        'Industrial &amp; Scientific', 'Automotive',
#        'Health & Personal Care', 'Movies & TV', 'Video Games',
#        'Industrial & Scientific',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION" />',
#        'Movies &amp; TV', 'All Beauty', 'Appliances',
#        '<img src="https://m.media-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#        'Grocery',
#        '<img src="https://m.media-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION" />',
#        '', 'Collectible Coins', 'Fire Phone', 'Apple Products',
#        'Beats by Dr. Dre', 'Amazon Fire TV', 'Gift Cards',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/img16/amazon-launchpad/content-grid/launchpad_lp_nav-logo_v2._CB268684856_.png" class="nav-categ-image" alt="AMAZON LAUNCHPAD"/>',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/handmade/brand/logos/2018/subnav_logo._CB502360610_.png" class="nav-categ-image" alt="Handmade"/>'],
#       dtype=object)

# %%
main_cat_counter = Counter(df_reviews.main_cat)

# %%
main_cat_counter.most_common()
# Out:
# [('Computers', 244665),
#  ('All Electronics', 129569),
#  ('Camera & Photo', 125075),
#  ('Home Audio & Theater', 102125),
#  ('Cell Phones & Accessories', 64356),
#  ('Car Electronics', 23218),
#  ('Sports & Outdoors', 9790),
#  ('Office Products', 8587),
#  ('Portable Audio & Accessories', 7678),
#  ('Tools & Home Improvement', 7341),
#  ('Camera &amp; Photo', 7295),
#  ('Home Audio &amp; Theater', 7051),
#  ('GPS & Navigation', 6526),
#  ('Amazon Home', 6186),
#  ('Automotive', 6183),
#  ('Industrial & Scientific', 4494),
#  ('', 4137),
#  ('Amazon Devices', 3827),
#  ('Musical Instruments', 3478),
#  ('<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#   2965),
#  ('Health & Personal Care', 2024),
#  ('Arts, Crafts & Sewing', 1689),
#  ('Cell Phones &amp; Accessories', 1655),
#  ('Toys & Games', 1488),
#  ('Video Games', 893),
#  ('All Beauty', 755),
#  ('Baby', 603),
#  ('Books', 521),
#  ('Pet Supplies', 386),
#  ('Software', 379),
#  ('Sports &amp; Outdoors', 358),
#  ('Tools &amp; Home Improvement', 326),
#  ('Portable Audio &amp; Accessories', 225),
#  ('Industrial &amp; Scientific', 103),
#  ('Health &amp; Personal Care', 85),
#  ('GPS &amp; Navigation', 77),
#  ('Grocery', 68),
#  ('<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION" />',
#   56),
#  ('Appliances', 47),
#  ('Toys &amp; Games', 44),
#  ('Arts, Crafts &amp; Sewing', 38),
#  ('<img src="https://m.media-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#   24),
#  ('Amazon Fire TV', 15),
#  ('Movies & TV', 12),
#  ('Fire Phone', 9),
#  ('Apple Products', 9),
#  ('Movies &amp; TV', 2),
#  ('<img src="https://images-na.ssl-images-amazon.com/images/G/01/img16/amazon-launchpad/content-grid/launchpad_lp_nav-logo_v2._CB268684856_.png" class="nav-categ-image" alt="AMAZON LAUNCHPAD"/>',
#   2),
#  ('<img src="https://images-na.ssl-images-amazon.com/images/G/01/handmade/brand/logos/2018/subnav_logo._CB502360610_.png" class="nav-categ-image" alt="Handmade"/>',
#   2),
#  ('<img src="https://m.media-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION" />',
#   1),
#  ('Collectible Coins', 1),
#  ('Beats by Dr. Dre', 1),
#  ('Gift Cards', 1)]

# %%
print("% of data selected = {}.".format(len(All_electronics)*100/len(df_reviews)))
# Out:
# % of data selected = 16.475277991467934.

# %%
selected_columns_values = ['Camera &amp; Photo', 'All Electronics',
       'Home Audio & Theater', 'Computers', 'Home Audio &amp; Theater',
       'Portable Audio &amp; Accessories', 'Portable Audio & Accessories',
       'Cell Phones &amp; Accessories', 'GPS &amp; Navigation', 'GPS & Navigation',
       'Camera & Photo', 'Cell Phones & Accessories','Car Electronics',
       'Amazon Devices','Video Games','Appliances', 'Apple Products',
       'Beats by Dr. Dre', 'Amazon Fire TV']
filtered_df = df_reviews[df_reviews.main_cat.isin(selected_columns_values)]

# %%
len(filtered_df)
# Out:
# 724686

# %%
All_electronics = filtered_df[filtered_df.main_cat == 'All Electronics']

# %%
All_electronics.head(10)
# Out:
#                                              category tech1  \
# 7   [Electronics, Portable Audio & Video, MP3 & MP...
# 14  [Electronics, eBook Readers &amp; Accessories,...
# 37  [Electronics, Accessories &amp; Supplies, Audi...
# 38  [Electronics, GPS, Finders & Accessories, GPS ...
# 39  [Electronics, GPS, Finders &amp; Accessories, ...
# 40  [Electronics, GPS, Finders & Accessories, Vehi...
# 47                          [Electronics, Headphones]
# 52  [Electronics, eBook Readers &amp; Accessories,...
# 58  [Electronics, eBook Readers & Accessories, Cov...
# 60  [Electronics, eBook Readers &amp; Accessories,...
#
#                                           description fit  \
# 7   [Support system: Windows XP/Vsita/7 * SNR: 85d...
# 14                                                 []
# 37  [The CLIKR-5 UR5U-8780L remote control is desi...
# 38  [Award-winning navigation and features of Rand...
# 39  [The Road Explorer  60 pairs award-winning nav...
# 40  [**** Shipped by 2-3 DAY UNITED STATES PRIORIT...
# 47  [Use these high quality headphones for interne...
# 52  [To make sure that your NOOK is charged and re...
# 58                                                 []
# 60                                                 []
#
#                                                 title  \
# 7   abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 14  BOOX Max Carta Ereader,13.3" Flexible Screen 1...
# 37  CLIKR-5 Time Warner Cable Remote Control UR5U-...
# 38                          Rand McNally RV Tablet 80
# 39                  Rand McNally Road Explorer 60 GPS
# 40  Rand McNally 528881469 7-inch Intelliroute TND...
# 47  Polaroid Pbm2200 PC / Gaming Stereo Headphones...
# 52  Barnes &amp; Noble NOOK Power Kit in Carbon BN...
# 58  Kate Spade Rain or Shine Magazine Cover for No...
# 60  Barnes &amp; Noble 7" Lautner Chocolate NOOK Case
#
#                                              also_buy tech2  \
# 7   [B01NAJ3KQB, B00WYSPT0C, B00AF40U5G, B00OFVNM4...
# 14                                                 []
# 37                           [B06VTZK822, B00OSI6O7S]
# 38                                       [B000BUQOGI]
# 39                                                 []
# 40                                                 []
# 47                                                 []
# 52                                                 []
# 58                                                 []
# 60                                                 []
#
#                  brand                                            feature  \
# 7           Crazy Cart  [Package Content: 1 x Display MP3 Player 1 x E...
# 14                BOOX  [Excellent Pinch Zooming Experience  -- Highli...
# 37                 URC                      [Instruction manual included]
# 38        Rand McNally  [Advanced navigation & trip planning, Wi-Ficon...
# 39        Rand McNally  [Award-winning navigation, Advanced, commercia...
# 40        Rand McNally  [Extra large 7-inch high-definition screen, En...
# 47            Polaroid  [Ideal for PC Internet chatting, PC / Console ...
# 52  Barnes &amp; Noble  [Dimensions - 2.5 W x 4 L x. 60 D (not includi...
# 58      Barnes & Noble                                                 []
# 60  Barnes &amp; Noble                                                 []
#
#                                                  rank  \
# 7   [>#177,454 in Electronics (See Top 100 in Elec...
# 14  [>#264,331 in Electronics (See Top 100 in Elec...
# 37  [>#4,971 in Electronics &gt; Accessories &amp;...
# 38  [>#4,892 in Electronics > Accessories & Suppli...
# 39  [>#177 in Electronics &gt; Accessories &amp; S...
# 40  [>#60 in Electronics > GPS & Navigation > Vehi...
# 47  [>#3,548,269 in Cell Phones &amp; Accessories ...
# 52  [>#85 in Electronics &gt; eBook Readers &amp; ...
# 58  [>#6,607 in Amazon Devices & Accessories (See ...
# 60  [>#9,109 in Electronics &gt; eBook Readers &am...
#
#                                             also_view         main_cat  \
# 7   [B01NAJ3KQB, B00OFVNM4G, B00L41WY8K, B07F34PNP...  All Electronics
# 14  [B077GVLMJN, B07BNGJXGS, B072DXXXN1, B07BYKZ9P...  All Electronics
# 37  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 38  [B01N5Q2YMO, B00YY3UBV2, B06XCBK7WB, B00CZ6WFX...  All Electronics
# 39  [B017WKSI3Q, B00N58RZ34, B07FKR7VZ4, B06XYPNDC...  All Electronics
# 40  [B00RVGXZBM, B00N58RZ34, B07FKR7VZ4, B06XCBK7W...  All Electronics
# 47                                                 []  All Electronics
# 52                                       [B01FGL2D84]  All Electronics
# 58                                                 []  All Electronics
# 60                                                 []  All Electronics
#
#                                          similar_item               date  \
# 7    class="a-bordered a-horizontal-stripes  a-spa...  December 28, 2012
# 14   class="a-bordered a-horizontal-stripes  a-spa...      June 30, 2016
# 37   class="a-bordered a-horizontal-stripes  a-spa...   January 31, 2013
# 38   class="a-bordered a-horizontal-stripes  a-spa...   October 23, 2015
# 39                                                        April 30, 2015
# 40                                                        April 15, 2010
# 47                                                     December 13, 2012
# 52                                                     September 4, 2011
# 58                                                     December 19, 2011
# 60                                                     December 12, 2012
#
#    price        asin                                           imageURL  \
# 7         0101635370  [https://images-na.ssl-images-amazon.com/image...
# 14        0285175270  [https://images-na.ssl-images-amazon.com/image...
# 37        0511189877  [https://images-na.ssl-images-amazon.com/image...
# 38        0528013475  [https://images-na.ssl-images-amazon.com/image...
# 39        0528012398  [https://images-na.ssl-images-amazon.com/image...
# 40        0528881469  [https://images-na.ssl-images-amazon.com/image...
# 47        0558835155  [https://images-na.ssl-images-amazon.com/image...
# 52        0594012015  [https://images-na.ssl-images-amazon.com/image...
# 58        0594287995                                                 []
# 60        0594450209  [https://images-na.ssl-images-amazon.com/image...
#
#                                       imageURLHighRes details
# 7   [https://images-na.ssl-images-amazon.com/image...     NaN
# 14  [https://images-na.ssl-images-amazon.com/image...     NaN
# 37  [https://images-na.ssl-images-amazon.com/image...     NaN
# 38  [https://images-na.ssl-images-amazon.com/image...     NaN
# 39  [https://images-na.ssl-images-amazon.com/image...     NaN
# 40  [https://images-na.ssl-images-amazon.com/image...     NaN
# 47  [https://images-na.ssl-images-amazon.com/image...     NaN
# 52  [https://images-na.ssl-images-amazon.com/image...     NaN
# 58                                                 []     NaN
# 60  [https://images-na.ssl-images-amazon.com/image...     NaN

# %%
total = len(All_electronics)

for category in All_electronics.columns:
    count = 0
    
    print(category, len(All_electronics.category))
    
    for val in All_electronics[category]:
        if val == [] or i == '' or len(i)<=2:
            count += 1
            
    print(category,(count/total)*100)
# Out:
# category 129569
# category 0.0
# tech1 129569
# tech1 0.0
# description 129569
# description 12.149511071321072
# fit 129569
# fit 0.0
# title 129569
# title 0.0
# also_buy 129569
# also_buy 85.9511148500027
# tech2 129569
# tech2 0.0
# brand 129569
# brand 0.0
# feature 129569
# feature 16.299423473207327
# rank 129569
# rank 1.2441247520626075
# also_view 129569
# also_view 74.9137525179634
# main_cat 129569
# main_cat 0.0
# similar_item 129569
# similar_item 0.0
# date 129569
# date 0.0
# price 129569
# price 0.0
# asin 129569
# asin 0.0
# imageURL 129569
# imageURL 37.451087837368505
# imageURLHighRes 129569
# imageURLHighRes 37.451087837368505
# details 129569
# details 0.0

# %% [markdown]
# ### Finding Null values

# %%
All_electronics.to_json('All_Electronics_file1.json', orient = "records")

# %% [markdown]
# ### EDA

# %%
count = 0
for i in All_electronics.feature:
    if i == '':
        count +=1
        
print(count*100/len(All_electronics))
# Out:
# 0.0

# %%
All_electronics.head(10)
# Out:
#                                              category tech1  \
# 7   [Electronics, Portable Audio & Video, MP3 & MP...
# 14  [Electronics, eBook Readers &amp; Accessories,...
# 37  [Electronics, Accessories &amp; Supplies, Audi...
# 38  [Electronics, GPS, Finders & Accessories, GPS ...
# 39  [Electronics, GPS, Finders &amp; Accessories, ...
# 40  [Electronics, GPS, Finders & Accessories, Vehi...
# 47                          [Electronics, Headphones]
# 52  [Electronics, eBook Readers &amp; Accessories,...
# 58  [Electronics, eBook Readers & Accessories, Cov...
# 60  [Electronics, eBook Readers &amp; Accessories,...
#
#                                           description fit  \
# 7   [Support system: Windows XP/Vsita/7 * SNR: 85d...
# 14                                                 []
# 37  [The CLIKR-5 UR5U-8780L remote control is desi...
# 38  [Award-winning navigation and features of Rand...
# 39  [The Road Explorer  60 pairs award-winning nav...
# 40  [**** Shipped by 2-3 DAY UNITED STATES PRIORIT...
# 47  [Use these high quality headphones for interne...
# 52  [To make sure that your NOOK is charged and re...
# 58                                                 []
# 60                                                 []
#
#                                                 title  \
# 7   abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 14  BOOX Max Carta Ereader,13.3" Flexible Screen 1...
# 37  CLIKR-5 Time Warner Cable Remote Control UR5U-...
# 38                          Rand McNally RV Tablet 80
# 39                  Rand McNally Road Explorer 60 GPS
# 40  Rand McNally 528881469 7-inch Intelliroute TND...
# 47  Polaroid Pbm2200 PC / Gaming Stereo Headphones...
# 52  Barnes &amp; Noble NOOK Power Kit in Carbon BN...
# 58  Kate Spade Rain or Shine Magazine Cover for No...
# 60  Barnes &amp; Noble 7" Lautner Chocolate NOOK Case
#
#                                              also_buy tech2  \
# 7   [B01NAJ3KQB, B00WYSPT0C, B00AF40U5G, B00OFVNM4...
# 14                                                 []
# 37                           [B06VTZK822, B00OSI6O7S]
# 38                                       [B000BUQOGI]
# 39                                                 []
# 40                                                 []
# 47                                                 []
# 52                                                 []
# 58                                                 []
# 60                                                 []
#
#                  brand                                            feature  \
# 7           Crazy Cart  [Package Content: 1 x Display MP3 Player 1 x E...
# 14                BOOX  [Excellent Pinch Zooming Experience  -- Highli...
# 37                 URC                      [Instruction manual included]
# 38        Rand McNally  [Advanced navigation & trip planning, Wi-Ficon...
# 39        Rand McNally  [Award-winning navigation, Advanced, commercia...
# 40        Rand McNally  [Extra large 7-inch high-definition screen, En...
# 47            Polaroid  [Ideal for PC Internet chatting, PC / Console ...
# 52  Barnes &amp; Noble  [Dimensions - 2.5 W x 4 L x. 60 D (not includi...
# 58      Barnes & Noble                                                 []
# 60  Barnes &amp; Noble                                                 []
#
#                                                  rank  \
# 7   [>#177,454 in Electronics (See Top 100 in Elec...
# 14  [>#264,331 in Electronics (See Top 100 in Elec...
# 37  [>#4,971 in Electronics &gt; Accessories &amp;...
# 38  [>#4,892 in Electronics > Accessories & Suppli...
# 39  [>#177 in Electronics &gt; Accessories &amp; S...
# 40  [>#60 in Electronics > GPS & Navigation > Vehi...
# 47  [>#3,548,269 in Cell Phones &amp; Accessories ...
# 52  [>#85 in Electronics &gt; eBook Readers &amp; ...
# 58  [>#6,607 in Amazon Devices & Accessories (See ...
# 60  [>#9,109 in Electronics &gt; eBook Readers &am...
#
#                                             also_view         main_cat  \
# 7   [B01NAJ3KQB, B00OFVNM4G, B00L41WY8K, B07F34PNP...  All Electronics
# 14  [B077GVLMJN, B07BNGJXGS, B072DXXXN1, B07BYKZ9P...  All Electronics
# 37  [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 38  [B01N5Q2YMO, B00YY3UBV2, B06XCBK7WB, B00CZ6WFX...  All Electronics
# 39  [B017WKSI3Q, B00N58RZ34, B07FKR7VZ4, B06XYPNDC...  All Electronics
# 40  [B00RVGXZBM, B00N58RZ34, B07FKR7VZ4, B06XCBK7W...  All Electronics
# 47                                                 []  All Electronics
# 52                                       [B01FGL2D84]  All Electronics
# 58                                                 []  All Electronics
# 60                                                 []  All Electronics
#
#                                          similar_item               date  \
# 7    class="a-bordered a-horizontal-stripes  a-spa...  December 28, 2012
# 14   class="a-bordered a-horizontal-stripes  a-spa...      June 30, 2016
# 37   class="a-bordered a-horizontal-stripes  a-spa...   January 31, 2013
# 38   class="a-bordered a-horizontal-stripes  a-spa...   October 23, 2015
# 39                                                        April 30, 2015
# 40                                                        April 15, 2010
# 47                                                     December 13, 2012
# 52                                                     September 4, 2011
# 58                                                     December 19, 2011
# 60                                                     December 12, 2012
#
#    price        asin                                           imageURL  \
# 7         0101635370  [https://images-na.ssl-images-amazon.com/image...
# 14        0285175270  [https://images-na.ssl-images-amazon.com/image...
# 37        0511189877  [https://images-na.ssl-images-amazon.com/image...
# 38        0528013475  [https://images-na.ssl-images-amazon.com/image...
# 39        0528012398  [https://images-na.ssl-images-amazon.com/image...
# 40        0528881469  [https://images-na.ssl-images-amazon.com/image...
# 47        0558835155  [https://images-na.ssl-images-amazon.com/image...
# 52        0594012015  [https://images-na.ssl-images-amazon.com/image...
# 58        0594287995                                                 []
# 60        0594450209  [https://images-na.ssl-images-amazon.com/image...
#
#                                       imageURLHighRes details
# 7   [https://images-na.ssl-images-amazon.com/image...     NaN
# 14  [https://images-na.ssl-images-amazon.com/image...     NaN
# 37  [https://images-na.ssl-images-amazon.com/image...     NaN
# 38  [https://images-na.ssl-images-amazon.com/image...     NaN
# 39  [https://images-na.ssl-images-amazon.com/image...     NaN
# 40  [https://images-na.ssl-images-amazon.com/image...     NaN
# 47  [https://images-na.ssl-images-amazon.com/image...     NaN
# 52  [https://images-na.ssl-images-amazon.com/image...     NaN
# 58                                                 []     NaN
# 60  [https://images-na.ssl-images-amazon.com/image...     NaN

# %%
All_electronics.replace('[]', np.NaN)
# Out:
#                                                  category tech1  \
# 7       [Electronics, Portable Audio & Video, MP3 & MP...
# 14      [Electronics, eBook Readers &amp; Accessories,...
# 37      [Electronics, Accessories &amp; Supplies, Audi...
# 38      [Electronics, GPS, Finders & Accessories, GPS ...
# 39      [Electronics, GPS, Finders &amp; Accessories, ...
# ...                                                   ...   ...
# 786360                          [Electronics, Headphones]
# 786361                          [Electronics, Headphones]
# 786385       [Electronics, Headphones, Earbud Headphones]
# 786404       [Electronics, Headphones, Earbud Headphones]
# 786431  [Electronics, Portable Audio & Video, MP3 & MP...
#
#                                               description fit  \
# 7       [Support system: Windows XP/Vsita/7 * SNR: 85d...
# 14                                                     []
# 37      [The CLIKR-5 UR5U-8780L remote control is desi...
# 38      [Award-winning navigation and features of Rand...
# 39      [The Road Explorer  60 pairs award-winning nav...
# ...                                                   ...  ..
# 786360                                                 []
# 786361                                                 []
# 786385                                                 []
# 786404  [About the product  Rhapsody & Mogan H9 is a m...
# 786431                                                 []
#
#                                                     title  \
# 7       abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 14      BOOX Max Carta Ereader,13.3" Flexible Screen 1...
# 37      CLIKR-5 Time Warner Cable Remote Control UR5U-...
# 38                              Rand McNally RV Tablet 80
# 39                      Rand McNally Road Explorer 60 GPS
# ...                                                   ...
# 786360  Wireless Bluetooth LED Stereo Headphone, Coste...
# 786361  Wireless Bluetooth LED Stereo Headphone, Coste...
# 786385  Bluetooth Headphones,Yostyle Wireless Headphon...
# 786404  Wireless Bluetooth Headset, HandsFree Wireless...
# 786431  Bluetooth FM Transmitter, JZxin Car FM Transmi...
#
#                                                  also_buy tech2         brand  \
# 7       [B01NAJ3KQB, B00WYSPT0C, B00AF40U5G, B00OFVNM4...          Crazy Cart
# 14                                                     []                BOOX
# 37                               [B06VTZK822, B00OSI6O7S]                 URC
# 38                                           [B000BUQOGI]        Rand McNally
# 39                                                     []        Rand McNally
# ...                                                   ...   ...           ...
# 786360                                                 []             Costech
# 786361                                                 []             Costech
# 786385                                       [B01I0U77O8]             Yostyle
# 786404                                                 []             snorain
# 786431                                                 []               JZxin
#
#                                                   feature  \
# 7       [Package Content: 1 x Display MP3 Player 1 x E...
# 14      [Excellent Pinch Zooming Experience  -- Highli...
# 37                          [Instruction manual included]
# 38      [Advanced navigation & trip planning, Wi-Ficon...
# 39      [Award-winning navigation, Advanced, commercia...
# ...                                                   ...
# 786360                                                 []
# 786361                                                 []
# 786385  [With Bluetooth V4.1, advanced apt-X technolog...
# 786404  [COMFORTABLE CUSTOM FIT  Rhapsody & Mogan nois...
# 786431                                                 []
#
#                                                      rank  \
# 7       [>#177,454 in Electronics (See Top 100 in Elec...
# 14      [>#264,331 in Electronics (See Top 100 in Elec...
# 37      [>#4,971 in Electronics &gt; Accessories &amp;...
# 38      [>#4,892 in Electronics > Accessories & Suppli...
# 39      [>#177 in Electronics &gt; Accessories &amp; S...
# ...                                                   ...
# 786360  [>#837,608 in Cell Phones & Accessories (See T...
# 786361  [>#1,182,349 in Cell Phones & Accessories (See...
# 786385  [>#186,311 in Cell Phones & Accessories (See T...
# 786404  [>#343,752 in Cell Phones & Accessories (See T...
# 786431  [>#173,851 in Cell Phones & Accessories (See T...
#
#                                                 also_view         main_cat  \
# 7       [B01NAJ3KQB, B00OFVNM4G, B00L41WY8K, B07F34PNP...  All Electronics
# 14      [B077GVLMJN, B07BNGJXGS, B072DXXXN1, B07BYKZ9P...  All Electronics
# 37      [B06VTZK822, B00OSI6O7S, B00KUL8O0W, B01BHEQQY...  All Electronics
# 38      [B01N5Q2YMO, B00YY3UBV2, B06XCBK7WB, B00CZ6WFX...  All Electronics
# 39      [B017WKSI3Q, B00N58RZ34, B07FKR7VZ4, B06XYPNDC...  All Electronics
# ...                                                   ...              ...
# 786360                                                 []  All Electronics
# 786361                                                 []  All Electronics
# 786385  [B01I0U77O8, B010RQWSE2, B00PGJWYJ0, B06X9BG9Z...  All Electronics
# 786404  [B01D3QZB2Y, B079GFF4HZ, B00XBZY0EI, B00S2P0M1...  All Electronics
# 786431  [B07BC99B8L, B06X9K9X1G, B07GDC29SR, B07CWNG32...  All Electronics
#
#                                              similar_item               date  \
# 7        class="a-bordered a-horizontal-stripes  a-spa...  December 28, 2012
# 14       class="a-bordered a-horizontal-stripes  a-spa...      June 30, 2016
# 37       class="a-bordered a-horizontal-stripes  a-spa...   January 31, 2013
# 38       class="a-bordered a-horizontal-stripes  a-spa...   October 23, 2015
# 39                                                            April 30, 2015
# ...                                                   ...                ...
# 786360                                                      October 17, 2016
# 786361                                                      October 17, 2016
# 786385   class="a-bordered a-horizontal-stripes  a-spa...      June 25, 2016
# 786404   class="a-bordered a-horizontal-stripes  a-spa...      June 25, 2016
# 786431   class="a-bordered a-horizontal-stripes  a-spa...     August 4, 2016
#
#         price        asin                                           imageURL  \
# 7              0101635370  [https://images-na.ssl-images-amazon.com/image...
# 14             0285175270  [https://images-na.ssl-images-amazon.com/image...
# 37             0511189877  [https://images-na.ssl-images-amazon.com/image...
# 38             0528013475  [https://images-na.ssl-images-amazon.com/image...
# 39             0528012398  [https://images-na.ssl-images-amazon.com/image...
# ...       ...         ...                                                ...
# 786360         B01HJ13BXA  [https://images-na.ssl-images-amazon.com/image...
# 786361         B01HJ13BZ8  [https://images-na.ssl-images-amazon.com/image...
# 786385  $9.91  B01HJ8E11E  [https://images-na.ssl-images-amazon.com/image...
# 786404         B01HJAPNHI  [https://images-na.ssl-images-amazon.com/image...
# 786431         B01HJFFHTC  [https://images-na.ssl-images-amazon.com/image...
#
#                                           imageURLHighRes details
# 7       [https://images-na.ssl-images-amazon.com/image...     NaN
# 14      [https://images-na.ssl-images-amazon.com/image...     NaN
# 37      [https://images-na.ssl-images-amazon.com/image...     NaN
# 38      [https://images-na.ssl-images-amazon.com/image...     NaN
# 39      [https://images-na.ssl-images-amazon.com/image...     NaN
# ...                                                   ...     ...
# 786360  [https://images-na.ssl-images-amazon.com/image...      {}
# 786361  [https://images-na.ssl-images-amazon.com/image...      {}
# 786385  [https://images-na.ssl-images-amazon.com/image...      {}
# 786404  [https://images-na.ssl-images-amazon.com/image...      {}
# 786431  [https://images-na.ssl-images-amazon.com/image...      {}
#
# [129569 rows x 19 columns]

# %%
All_electronics.to_pickle("Filtered_Electronics.pkl")
